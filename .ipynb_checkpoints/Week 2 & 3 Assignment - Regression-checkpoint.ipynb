# %%
pip install pandas matplotlib seaborn numpy scipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
data = pd.read_csv("C:\\Users\\aniru\\OneDrive\\Documents\\DATA MINING\\housing.csv")

# %%
data.head()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data.tail()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# ...

# %%
print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
data.shape
# Out:
# (20640, 10)

# %%
data.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
# Data types of input features
data_types = data.dtypes

# %%
# Summary statistics
summary_stats = data.describe()

# %%
# Correlation matrix
correlation_matrix = data.corr(numeric_only=True)

# %%
import matplotlib.pyplot as plt

# %%
# Summary statistics for the "median_house_value" feature
median_house_value_summary = data['median_house_value'].describe()

# Distribution of the "total_rooms" feature
plt.hist(data['housing_median_age'], bins=50, color='skyblue', edgecolor='green')
plt.xlabel('Median House Value')
plt.ylabel('Frequency')
plt.title('Distribution of Median House Value')
plt.show()

# Display summary statistics
print("Summary Statistics for Median House Value:")
print(median_house_value_summary)
# Out:
# Summary Statistics for Median House Value:
# count     20640.000000
# mean     206855.816909
# std      115395.615874
# min       14999.000000
# 25%      119600.000000
# 50%      179700.000000
# 75%      264725.000000
# max      500001.000000
# Name: median_house_value, dtype: float64

# %%
import seaborn as sns

# Countplot for "ocean_proximity"
sns.countplot(data=data, x='ocean_proximity', palette='viridis')
plt.xlabel('Ocean Proximity')
plt.ylabel('Count')
plt.title('Distribution of Ocean Proximity')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

# %%
# Histogram for 'housing_median_age'
plt.hist(data['housing_median_age'], bins=20)
plt.xlabel('Housing Median Age')
plt.ylabel('Frequency')
plt.title('Distribution of Housing Median Age')
plt.show()

# Histogram for 'population'
plt.hist(data['population'], bins=20)
plt.xlabel('Population')
plt.ylabel('Frequency')
plt.title('Distribution of Population')
plt.show()

# Histogram for 'households'
plt.hist(data['households'], bins=20)
plt.xlabel('Number of Households')
plt.ylabel('Frequency')
plt.title('Distribution of Number of Households')
plt.show()

#In this code, we are creating two separate histograms:
#The first histogram (housing_median_age) visualizes the distribution of the "Housing Median Age" feature, which represents the median age of housing units in a specific area.
#The second histogram (population) visualizes the distribution of the "Population" feature, which represents the total population in a specific area.
#These histograms help us understand the distributions of these features, showing the ranges and frequencies of different values within each feature. You can use similar code to explore other numerical features in your dataset.

# %%
# Scatter plot of "median_income" vs."median_house_value"
plt.scatter(data['median_income'], data['median_house_value'])
plt.xlabel('Median Income')
plt.ylabel('Median House Value')
plt.title('Scatter Plot: Median Income vs. Median House Value')
plt.grid(True, linestyle='--')  # Add grid lines
plt.show()

# %%
# Scatter plot of "housing_median_age" vs. "median_house_value"
plt.scatter(data['housing_median_age'], data['median_house_value'], color='orange')
plt.xlabel('Housing Median Age')
plt.ylabel('Median House Value')
plt.title('Scatter Plot: Housing Median Age vs. Median House Value')
plt.grid(True, linestyle='--')  # Add grid lines
plt.show()

# %%
#1. Split Data into Train/Test Sets:

#In regression modeling, it's 
#common to split the data into training and testing sets to assess how well the model generalizes to unseen data. 
#We'll use 80% of the data for training and 20% for testing.


from sklearn.model_selection import train_test_split

# Define the features (input) and target (output) variables
X = data[['median_income']]  # Using 'median_income' as the feature
y = data['median_house_value']  # 'median_house_value' as the target variable


# Split the data into training and testing sets (80% training, 20% testing)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=7557)

# %%
#2.Fit OLS Regression Model on Training Data:
#Now, let's create and fit an OLS regression model using the training data.

from sklearn.linear_model import LinearRegression

# Create a Linear Regression model
ols_model = LinearRegression()

# Fit the model on the training data
ols_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
#Evaluate model performance on training and test sets (use at least one: RMSE, R-squared, residuals plots)

from sklearn.metrics import mean_squared_error, r2_score
import numpy as np
y_train_pred = ols_model.predict(X_train)
y_test_pred = ols_model.predict(X_test)
rmse_train = np.sqrt(mean_squared_error(y_train, y_train_pred))
rmse_test = np.sqrt(mean_squared_error(y_test, y_test_pred))
r2_train = r2_score(y_train, y_train_pred)
r2_test = r2_score(y_test, y_test_pred)
plt.scatter(y_train_pred, y_train_pred - y_train, c='blue', marker='o', label='Training data')
plt.scatter(y_test_pred, y_test_pred - y_test, c='green', marker='s', label='Testing data')
plt.xlabel('Predicted values')
plt.ylabel('Residuals')
plt.legend(loc='upper left')
plt.title('Residuals Plot')
plt.axhline(y=0, color='red', linestyle='--')
plt.show()
print(f'Training RMSE: {rmse_train:.2f}')
print(f'Testing RMSE: {rmse_test:.2f}')
print(f'Training R-squared: {r2_train:.2f}')
print(f'Testing R-squared: {r2_test:.2f}')
# Out:
# Training RMSE: 83722.95
# Testing RMSE: 83776.19
# Training R-squared: 0.47
# Testing R-squared: 0.47

# %%
# Get the coefficient (weight) of the feature 'median_income'
coefficient = ols_model.coef_

print(f'Coefficient (Weight) for "median_income": {coefficient[0]:.2f}')
# Out:
# Coefficient (Weight) for "median_income": 41828.28

# %%
#Feature Transformation, Interaction Terms, and Polynomial Features:
#1.Feature Transformation (Scaling):
from sklearn.preprocessing import StandardScaler

# Create a scaler object
scaler = StandardScaler()

# Scale the feature 'median_income'
data['median_income_scaled'] = scaler.fit_transform(data[['median_income']])

# 2.Interaction Terms:

# Create an interaction term between 'housing_median_age' and 'population'
data['age_population_interaction'] = data['housing_median_age'] * data['population']

#3. Polynomial Features:
from sklearn.preprocessing import PolynomialFeatures

# Create polynomial features for 'housing_median_age'
poly = PolynomialFeatures(degree=2)
data_poly = poly.fit_transform(data[['housing_median_age']])

# %%
#Evaluate different regression algorithms (lasso, ridge, etc)

from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.metrics import mean_squared_error

# Create and train Linear Regression model
linear_model = LinearRegression()
linear_model.fit(X_train, y_train)

# Create and train Lasso Regression model
lasso_model = Lasso(alpha=0.1)  # You can adjust the regularization parameter 'alpha'
lasso_model.fit(X_train, y_train)

# Create and train Ridge Regression model
ridge_model = Ridge(alpha=1.0)  # You can adjust the regularization parameter 'alpha'
ridge_model.fit(X_train, y_train)
# Out:
# Ridge()

# %%
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.metrics import mean_squared_error

# Create and train Linear Regression model
linear_model = LinearRegression()
linear_model.fit(X_train, y_train)

# Create and train Lasso Regression model
lasso_model = Lasso(alpha=0.1)  # You can adjust the regularization parameter 'alpha'
lasso_model.fit(X_train, y_train)

# Create and train Ridge Regression model
ridge_model = Ridge(alpha=1.0)  # You can adjust the regularization parameter 'alpha'
ridge_model.fit(X_train, y_train)

# Calculate mean squared error for each model
linear_mse = mean_squared_error(y_test, linear_model.predict(X_test))
lasso_mse = mean_squared_error(y_test, lasso_model.predict(X_test))
ridge_mse = mean_squared_error(y_test, ridge_model.predict(X_test))

# Select the model with the lowest MSE
best_model = None
if linear_mse <= lasso_mse and linear_mse <= ridge_mse:
    best_model = "Linear Regression"
elif lasso_mse <= linear_mse and lasso_mse <= ridge_mse:
    best_model = "Lasso Regression"
else:
    best_model = "Ridge Regression"

print(f"Best Performing Model: {best_model}")
# Out:
# Best Performing Model: Ridge Regression

# %%
#Introduction
#Brief background on the dataset and regression problem to solve.
#The California Housing Prices dataset is a publicly available dataset that contains information about housing prices in California in the early 1990s. The dataset was created by the California Department of Housing and Community Development.
#The dataset includes data on a variety of factors, including Longitude, latitude housing_median_age, total_rooms, total_bedrooms, population, households, median_income, median_house_value and ocean_proximity.
#The data set have an observation of 20640 rows and 10 columns.
#So, what we are working here is with basically the districts in California. For each district we have the locations in terms of latitudes and longitudes and a bunch of features about their housing market such that the median age of the houses within that district or the total rooms of all the houses within that district and total bathrooms and population and so forth. One of the interesting things here is that the ocean proximity is not a feature that is not numeric. 
#There are a variety of factors that can influence the price of a home. Some of the most important factors include:
#Location: Homes in more desirable locations, such as near city centre’s or in well-established neighbourhoods, are typically more expensive.
#Condition: Homes in good condition are typically more expensive than homes that need repairs.
#The California Housing Prices dataset can be used to study the relationship between these factors and housing prices. For example, researchers can use the dataset to determine how much of an impact location has on housing prices, or how much of an impact the condition of a home has on its price.

                                  
                          #REGRESSION PROBLEMS TO SOLVE
#There are several regression problems that could be solved using the California Housing Prices dataset.
#To Predict house prices let us imagine you want to guess how much a house costs in an area. You can use information like the age of houses, the number of rooms, bedrooms, people living there, households, and income. This helps buyers, sellers, and government folks and here are some specific examples of regression models that could be used.
#Linear regression: Linear regression is a simple but powerful regression model that can be used to predict a continuous variable (such as median house value) based on one or more other variables.
#Ridge Regression :Imagine you have lots of information about houses, but some of it is kind of similar. Ridge regression helps you make predictions even when some of your information is quite alike.
#Lasso Regression: Lasso is like Ridge, but it's picky. It helps you pick only the most important information to make predictions. It's like choosing the most crucial puzzle pieces to solve a bigger picture.

#Random Forest: Think of this as a team of experts making predictions together. Each expert gives their opinion, and the group decision is often more accurate. It's like getting advice from multiple friends before making a decision.
            
#The histogram and summary statistics you provided tell us a lot about the distribution of median house values in the California Housing Prices dataset.
#The histogram shows that the median house values are not evenly distributed. There is a peak in the histogram at around $200,000, which means that there are more houses with median house values in this range than any other range. Most houses in the dataset have a median value of around $200,000, making it the most common price range. The histogram is skewed to the right, indicating that there are relatively few houses with very high median values, creating a long tail on the right side. The concentration of houses in the lower to middle price range suggests that many houses in California are relatively affordable.
#Summary Statistics for Median House Value:
#count     20640.000000.  there are 20640 houses in the data set.
#mean     206855.816909: The average median house value is approximately $206,856.
#std      115395.615874 : Values vary around the mean by about $115,396 on average.
#min       14999.000000 : The lowest median value
#25%      119600.000000: 25% of houses have values at or below $119,600.
#50%      179700.000000: The middle value is $179,700; half the houses are below, half above.
#75%      264725.000000: 5% of houses have values at or below $264,725
#max      500001.000000. The highest median value
#Name: median_house_value, dtype: float64.
 
                                    
#The scatter plot shows the relationship between two variables: median income and median house value. The x-axis represents median income, and the y-axis represents median house value. 
#The plot shows a positive correlation between median income and median house value. This means that, on average, houses in areas with higher median incomes tend to be more expensive.
#It shows that when median income rises, median house values tend to go up as well. This is because wealthier areas often have pricier homes due to better amenities.
#However, there's variation; sometimes, high-income areas have affordable homes, and low-income areas have expensive ones. This suggests that other factors like location and house size play roles too.

                              

#The scatter plot shows a negative correlation between housing median age and median house value. This means that, on average, older houses tend to be less expensive than newer houses. The scatter plot shows that there is a wide range of prices for both older and newer houses. However, the most expensive houses in the dataset are generally newer houses, and the least expensive houses in the dataset are generally older houses. There are several possible explanations for the negative correlation between housing median age and median house value. One possibility is that older houses are often smaller and in less desirable locations than newer houses. Another possibility is that older houses may require more repairs and maintenance than newer houses. This can make older houses less attractive to buyers, which can drive down their prices.
  
                                    
#The residual plot shows the relationship between the predicted values of the median house value and the residuals (the difference between the predicted values and the actual values) for the training and testing data.
#The residual plot shows that the residuals are randomly distributed around the zero line. This means that the linear regression model is a good fit for the data.
#The residual plot also shows that the residuals are slightly larger for the testing data than for the training data. This is to be expected, since the model was trained on the training data and is being evaluated on the testing data, which it has never seen before.
#Overall, the residual plot shows that the linear regression model is a good fit for the data and that it is able to make accurate predictions for the median house value.

#Training RMSE: 83722.95
#Testing RMSE: 83776.19
#Training R-squared: 0.47
#Testing R-squared: 0.47. 

#The training RMSE of 83722.95 and testing RMSE of 83776.19 indicate that the linear regression model is able to make reasonably accurate predictions for the median house value, but there is still some room for improvement. The R-squared values of 0.47 for both the training and testing data indicate that the linear regression model is able to explain about 47% of the variation in the median house value. This is a moderate to high R-squared value, suggesting that the model is a good fit for the data. Overall, the training and testing RMSE and R-squared values indicate that the linear regression model is a good starting point for predicting the median house value. However, there may be other factors that can be included in the model to improve its accuracy.

                  #Summarize performance of original and best model
#The original Linear Regression model provided moderate performance with an R-squared value of 0.47 and an RMSE of approximately 83776.19 on the testing data.
#The best-performing model, Ridge Regression, was selected based on its lowest MSE and provided similar performance to the original Linear Regression model.
#Collecting additional data related to housing market dynamics, economic indicators, or geographic factors could enhance predictions.
#The key coefficients in the Ridge Regression model represent the relationships between the features and the target variable (median house value). These coefficients indicate the impact of each feature on the predicted house value.
#Linear models assume a linear relationship between features and the target, which may not hold for all cases.
